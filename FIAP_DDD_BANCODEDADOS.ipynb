# %% [markdown]
# # FIAP
# ## WEB DESIGN
# ### DDD - Python
#
# Banco de Dados:
#
# - Oracle - SQL Developer: Ambiente da FIAP em nuvem
# - MySQL - MySQL Workbench: Local
# - SQLite - SQL Studio: Local
#
# Objetivo da aula de hoje
#
# - Visão geral de BD para ambiente corporativo/negócios
# - Instalar Banco de Dados
# - Instalar ferramentas para acesso e  uso do banco de dados
# - Conectar com o banco de dados via Python
# - Instalar driver do BD
# - Criar tabela
# - Realizar operações SQL via python
#   - Insert
#   - Update
#   - Delete

# %% [markdown]
# Oracle e MySQL são so BDs mais populares
#
# https://w3techs.com/

# %% [markdown]
# Popularidade dos bancos de dados...
#
# ![image.png](attachment:image.png)
#
# https://db-engines.com/en/ranking

# %% [markdown]
# Tipos de banco de dados
#
# ![image.png](attachment:image.png)
#
# https://ehgomes.com.br/banco-de-dados/sgbd-sistema-gerenciador-de-banco-de-dado-o-que-e/

# %% [markdown]
# Oracle - SQL Developer
#
# ![image.png](attachment:image.png)

# %% [markdown]
# SQLite - SQLite Studio
#
# ![image.png](attachment:image.png)

# %% [markdown]
# MySQL Community - MySQL Workbanch
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# https://dataengineeringcentral.substack.com/p/sql-vs-python-data-pipelines
